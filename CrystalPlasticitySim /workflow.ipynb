# %%
from mutiagent import run_query_through_graph

query = """
Optimize the three independent deformation gradients (F12, F13, F23) 
in the load file within the range of -0.00300 to 0.00300. The goal is to 
minimize the deviation angle between the simulated orientation quaternion 
from the DAMASK simulation and the experimental orientation quaternion 
[0.03451538, 0.56773038, 0.38495706, 0.72684178] within a 1-degree threshold. 
The initial configuration files for the DAMASK simulation are available 
in the 'workdir' folder. Perform optimization iteratively by adjusting 
F12, F13, and F23, running the DAMASK simulation, and computing the 
deviation angle. Use an efficient optimization algorithm to find the optimal 
deformation gradient values. Create a csvfile 'optimization_results.csv' to 
log the current values of F12, F13, and F23, and its simulation quaternion, 
along with the computed deviation angle for each iteration of the optimization process. 
And save the figure of how the best (minimum) deviation angle evolves during an optimization process.
"""

run_query_through_graph(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 19
#       1 from mutiagent import run_query_through_graph
#       3 query = """
#       4 Optimize the three independent deformation gradients (F12, F13, F23)
#       5 in the load file within the range of -0.00300 to 0.00300. The goal is to
#    (...)
#      16 And save the figure of how the best (minimum) deviation angle evolves during an optimization process.
#      17 """
# ---> 19 run_query_through_graph(query)
#
# TypeError: run_query_through_graph() missing 1 required positional argument: 'thread_id'

# %%
from mutiagent import run_query_through_graph

query = """
Optimize the three independent deformation gradients (F12, F13, F23) in the load file 
within the range of -0.00300 to 0.00300. The objective is to minimize the deviation angle 
between the simulated orientation quaternion (from DAMASK) and the experimental orientation 
quaternion [0.03451538, 0.56773038, 0.38495706, 0.72684178], targeting a deviation below 1 degree.

Use the initial DAMASK configuration files provided in the 'workdir' folder. 
Perform the optimization iteratively by adjusting F12, F13, and F23, running the DAMASK simulation, 
and computing the deviation angle at each step. Apply an efficient optimization algorithm 
to identify the optimal set of deformation gradients.

Log the results of each iteration in a CSV file named 'optimization_results.csv', including:
- the current values of F12, F13, and F23
- the resulting simulation quaternion
- the computed deviation angle

Additionally, track and save a plot showing the evolution of the best (minimum) deviation angle 
found so far across all iterations of the optimization process.
"""

run_query_through_graph(query)
# Out:
# ((), {'supervisor': {'next': 'coder'}})
# ----
# ...

# %%
from mutiagent import run_query_through_graph

query = """
Optimize the slip-related material parameters in the DAMASK material file for the Ni₃Al17-A1 alloy.
The goal is to reduce the error between the simulated and experimental stress-strain curves.

Focus on tuning the following parameters related to slip behavior:

the stress exponent for slip (integer, range: 10 to 80)

the initial critical shear stress for slip (float, range: 5 MPa to 20 MPa)

the maximum critical shear stress for slip (float, range: 10 MPa to 50 MPa)

the initial hardening modulus for slip-slip interactions (float, range: 100 MPa to 10 GPa)

Use the provided DAMASK simulation files and experimental data located in the workdir folder.

Apply an efficient optimization algorithm to find the parameter set that minimizes the error.

Log the results of each iteration in a file named optimization_results.csv, including:

the current values of the four parameters

the computed error

Also, save a plot showing how the best (lowest) error improves across the optimization iterations.


"""

run_query_through_graph(query)
# Out:
# ((), {'supervisor': {'next': 'coder'}})
# ----
# ...

# %%
from mutiagent import run_query_through_graph

query = """
Optimize the slip-related material parameters in the DAMASK material file for the Ni₃Al17-A1 alloy.
The goal is to reduce the error between the simulated and experimental stress-strain curves.

Focus on tuning the following parameters related to slip behavior:

the stress exponent for slip (integer, range: 10 to 80)

the initial critical shear stress for slip (float, range: 5 MPa to 30 MPa)

the maximum critical shear stress for slip (float, range: 10 MPa to 50 MPa)

the initial hardening modulus for slip-slip interactions (float, range: 100 MPa to 10 GPa)

Use the provided DAMASK simulation files and experimental data located in the workdir folder.

Apply an efficient optimization algorithm to find the parameter set that minimizes the error.

Log the results of each iteration in a file named optimization_results.csv, including:

the current values of the four parameters

the computed error

Also, save a plot showing how the best (lowest) error improves across the optimization iterations.


"""

run_query_through_graph(query)

# %%
from mutiagent import run_query_through_graph

query = """
Optimize the slip-related material parameters in the DAMASK material file for the Ni₃Al17-A1 alloy.
The goal is to reduce the mean absolute percentage error between experimental and the simulated stress-strain curves under 0.1 but the experimental data is noncontinuous.

Focus on tuning the following parameters related to slip behavior:

the initial critical shear stress for slip (range: 27 MPa to 90 MPa)

the maximum critical shear stress for slip (range: 1000MPa to 5000 MPa)

the initial hardening modulus for slip-slip interactions (range: 100 MPa to 500 MPa)

The DAMASK simulation files and experimental data are located in the workdir folder.

Apply efficient optimization algorithms to find the parameter set that minimizes the error.

Log the results of each iteration in a file named optimization_results.csv, including:

the current values of the four parameters

the computed error

"""

run_query_through_graph(query,2)
# Out:
# ((), {'supervisor': {'next': 'coder'}})
# ----
# ...

# %%
from mutiagent import run_query_through_graph

query = "plot the strain-stress curve of the simulation with Minimum Error and the experiment in the same figure, and save it as a png file"
run_query_through_graph(query,2)
# Out:
# ((), {'supervisor': {'next': 'simulator'}})
# ----
# ...

# %%
query = "plot the strain-stress curve of the simulation with Minimum Error and the experiment in the same figure, and save it as a png file, the minimum error case saves in the optimization_results.csv"
run_query_through_graph(query,2)
# Out:
# ((), {'supervisor': {'next': 'coder'}})
# ----
# ...

# %%
from mutiagent import run_query_through_graph

query = """
Optimize the slip-related material parameters in the DAMASK material file for the Ni₃Al17-A1 alloy.
The goal is to reduce the mean absolute percentage error between experimental and the simulated stress-strain curves under 0.1.

Focus on tuning the following parameters related to slip behavior:

the initial critical shear stress for slip (an integer in the range: 27 MPa to 90 MPa)

the maximum critical shear stress for slip (an integer in the range: 1000MPa to 5000 MPa)

the initial hardening modulus for slip-slip interactions (an integer in the range: 100 MPa to 500 MPa)

The DAMASK simulation files and experimental data are located in the workdir folder.

Before starting the optimization, clean the experimental stress-strain data.

Apply efficient optimization algorithms to find the parameter set that minimizes the error.

Log the full optimization process in a CSV file named optimization_results.csv, including:

the current values of the four parameters

the current computed error

"""

run_query_through_graph(query,2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mutiagent import run_query_through_graph
#       3 query = """
#       4 Optimize the slip-related material parameters in the DAMASK material file for the Ni₃Al17-A1 alloy.
#       5 The goal is to reduce the mean absolute percentage error between experimental and the simulated stress-strain curves under 0.1.
#    (...)
#      26
#      27 """
#      29 run_query_through_graph(query,2)
#
# File ~/Library/CloudStorage/OneDrive-国立研究開発法人物質・材料研究機構/自分/langchain/damask-agentv9-2-1/mutiagent.py:14
#      12 from langchain_core.tools import tool
#      13 from langchain_experimental.utilities import PythonREPL
# ---> 14 from workdir.damask_yaml import update_material_properties
#      15 from workdir.damask_yaml import update_load_yaml
#      16 from workdir.damask_simulation import run_damask_simulation
# ...
